# %% [markdown]
# ### Google Colab Setup

# %% [markdown]
# Before getting started we need to run some standard code to set up our environment. You'll need to execute this code again each time you start the notebook.
#
# First, run this cell to load the [autoreload](https://ipython.readthedocs.io/en/stable/config/extensions/autoreload.html?highlight=autoreload) extension. This enables us to modify `.py` source files and reintegrate them into the notebook, ensuring a smooth editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded assignment1
# Example: If you create a Fall2023 folder and put all the files under A1 folder, then 'Fall2023/A1'
GOOGLE_DRIVE_PATH_POST_MYDRIVE = 'Colab Notebooks/Group-Project'
GOOGLE_DRIVE_PATH = os.path.join('/content', 'drive', 'MyDrive', GOOGLE_DRIVE_PATH_POST_MYDRIVE)
print(os.listdir(GOOGLE_DRIVE_PATH))
# Out:
# ['notebooks', '.git', 'dataset-screening', 'paper', 'data', 'model', 'scripts', 'README.md', '.gitignore', 'requirements.txt', 'config', 'logs', 'plot']

# %% [markdown]
# ### Local Setup or Google Colab
# Run the cell below regardless of setup to set the path

# %%
# if running locally set GOOGLE PATH
import sys
if 'google.colab' in sys.modules:
  print(f'Running in google colab. Our path is `{GOOGLE_DRIVE_PATH}`')
else:
  GOOGLE_DRIVE_PATH = '.'
  print('Running locally.')
# Out:
# Running in google colab. Our path is `/content/drive/MyDrive/Colab Notebooks/Group-Project`

# %% [markdown]
# # Env setup & package installation

# %%
# !bash "{GOOGLE_DRIVE_PATH}/config/setup_env.sh"
# Out:
# ⏬ Downloading https://github.com/jaimergp/miniforge/releases/download/24.11.2-1_colab/Miniforge3-colab-24.11.2-1_colab-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:06
# 🔁 Restarting kernel...
# Traceback (most recent call last):
#   File "<string>", line 1, in <module>
#   File "/usr/local/lib/python3.11/dist-packages/condacolab.py", line 207, in install_miniforge
#     install_from_url(
#   File "/usr/local/lib/python3.11/dist-packages/condacolab.py", line 169, in install_from_url
#     get_ipython().kernel.do_shutdown(True)
#     ^^^^^^^^^^^^^^^^^^^^
# AttributeError: 'NoneType' object has no attribute 'kernel'
# Channels:
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pinsage_env
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.7.14  |       hbd8a1cb_0         152 KB  conda-forge
#     icu-75.1                   |       he02047a_0        11.6 MB  conda-forge
#     ld_impl_linux-64-2.44      |       h1423503_1         660 KB  conda-forge
#     libexpat-2.7.1             |       hecca717_0          73 KB  conda-forge
#     libffi-3.4.6               |       h2dba641_1          56 KB  conda-forge
#     libgcc-15.1.0              |       h767d61c_3         806 KB  conda-forge
#     libgcc-ng-15.1.0           |       h69a702a_3          28 KB  conda-forge
#     libgomp-15.1.0             |       h767d61c_3         437 KB  conda-forge
#     liblzma-5.8.1              |       hb9d3cd8_2         110 KB  conda-forge
#     libnsl-2.0.1               |       hb9d3cd8_1          33 KB  conda-forge
#     libsqlite-3.50.3           |       hee844dc_1         914 KB  conda-forge
#     libstdcxx-15.1.0           |       h8f9b012_3         3.7 MB  conda-forge
#     libstdcxx-ng-15.1.0        |       h4852527_3          28 KB  conda-forge
#     ncurses-6.5                |       h2d0b736_3         871 KB  conda-forge
#     openssl-3.5.1              |       h7b32b05_0         3.0 MB  conda-forge
#     pip-25.1.1                 |     pyh8b19718_0         1.2 MB  conda-forge
#     python-3.10.18             |hd6af730_0_cpython        23.9 MB  conda-forge
#     readline-8.2               |       h8c095d6_2         276 KB  conda-forge
#     setuptools-80.9.0          |     pyhff2d567_0         731 KB  conda-forge
#     tk-8.6.13                  |noxft_hd72426e_102         3.1 MB  conda-forge
#     tzdata-2025b               |       h78e105d_0         120 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        51.6 MB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_gnu
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-h4bc722e_7
#   ca-certificates    conda-forge/noarch::ca-certificates-2025.7.14-hbd8a1cb_0
#   icu                conda-forge/linux-64::icu-75.1-he02047a_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.44-h1423503_1
#   libexpat           conda-forge/linux-64::libexpat-2.7.1-hecca717_0
#   libffi             conda-forge/linux-64::libffi-3.4.6-h2dba641_1
#   libgcc             conda-forge/linux-64::libgcc-15.1.0-h767d61c_3
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-15.1.0-h69a702a_3
#   libgomp            conda-forge/linux-64::libgomp-15.1.0-h767d61c_3
#   liblzma            conda-forge/linux-64::liblzma-5.8.1-hb9d3cd8_2
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hb9d3cd8_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.50.3-hee844dc_1
#   libstdcxx          conda-forge/linux-64::libstdcxx-15.1.0-h8f9b012_3
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-15.1.0-h4852527_3
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libzlib            conda-forge/linux-64::libzlib-1.3.1-hb9d3cd8_2
#   ncurses            conda-forge/linux-64::ncurses-6.5-h2d0b736_3
#   openssl            conda-forge/linux-64::openssl-3.5.1-h7b32b05_0
#   pip                conda-forge/noarch::pip-25.1.1-pyh8b19718_0
#   python             conda-forge/linux-64::python-3.10.18-hd6af730_0_cpython
#   readline           conda-forge/linux-64::readline-8.2-h8c095d6_2
#   setuptools         conda-forge/noarch::setuptools-80.9.0-pyhff2d567_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_hd72426e_102
#   tzdata             conda-forge/noarch::tzdata-2025b-h78e105d_0
#   wheel              conda-forge/noarch::wheel-0.45.1-pyhd8ed1ab_1
#
#
#
# Downloading and Extracting Packages:
# python-3.10.18       | 23.9 MB   | :   0% 0/1 [00:00<?, ?it/s]
# icu-75.1             | 11.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tk-8.6.13            | 3.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# pip-25.1.1           | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# libsqlite-3.50.3     | 914 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libgcc-15.1.0        | 806 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :   3% 0.026824578825392815/1 [00:00<00:03,  3.74s/it]
# icu-75.1             | 11.6 MB   | :  28% 0.280964215043643/1 [00:00<00:00,  2.81it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | :  82% 0.8241603097417698/1 [00:00<00:00,  8.23it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | :   6% 0.06279395541746699/1 [00:00<00:01,  1.60s/it]
#
#
# tk-8.6.13            | 3.1 MB    | :  54% 0.5386186063331226/1 [00:00<00:00,  5.22it/s]
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  8.23it/s]
#
#
# tk-8.6.13            | 3.1 MB    | : 100% 1.0/1 [00:00<00:00,  5.22it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.60s/it]
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :  16% 0.15833044087183076/1 [00:00<00:00,  1.14s/it]
# icu-75.1             | 11.6 MB   | :  93% 0.925290804350459/1 [00:00<00:00,  4.94it/s]
#
#
#
#
# pip-25.1.1           | 1.2 MB    | :   1% 0.013181066697774328/1 [00:00<00:15, 15.21s/it]
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | :   2% 0.018375108367605347/1 [00:00<00:11, 12.16s/it]
#
#
#
#
#
# libsqlite-3.50.3     | 914 KB    | : 100% 1.0/1 [00:00<00:00, 10.93s/it]
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:00<00:00, 12.16s/it]
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:00<00:00, 15.21s/it]
#
#
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :  35% 0.34806526670997506/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | :   2% 0.021880692532465797/1 [00:00<00:14, 14.39s/it]
#
#
#
#
#
#
#
# libgcc-15.1.0        | 806 KB    | : 100% 1.0/1 [00:00<00:00, 14.36s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | :   2% 0.02423510895740514/1 [00:00<00:13, 13.32s/it]
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:00<00:00, 14.39s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:00<00:00, 13.32s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | :   4% 0.036647668811008616/1 [00:00<00:09,  9.98s/it]
#
#
#
#
#
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :  54% 0.5371458345279878/1 [00:00<00:00,  1.56it/s]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | :   6% 0.05800056641178136/1 [00:00<00:06,  6.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:00<00:00,  6.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | :  11% 0.10525639543100901/1 [00:00<00:03,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | :  13% 0.1332379155552664/1 [00:00<00:02,  3.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:00<00:00,  3.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:00<00:00,  3.13s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | :  15% 0.1451272875440679/1 [00:00<00:02,  3.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:00<00:00,  3.11s/it]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:00<00:00,  4.94it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | :  29% 0.2852715337871955/1 [00:00<00:01,  1.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:00<00:00,  1.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | :  22% 0.2190052265041237/1 [00:00<00:01,  2.15s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :  74% 0.7386573047284997/1 [00:00<00:00,  1.72it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libstdcxx-15.1.0     | 3.7 MB    | : 100% 1.0/1 [00:00<00:00,  8.23it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | :  49% 0.4857252972043521/1 [00:00<00:00,  1.07s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:00<00:00,  1.07s/it]
#
#
#
#
#
# libsqlite-3.50.3     | 914 KB    | : 100% 1.0/1 [00:00<00:00,  1.99it/s]
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | :  97% 0.9663390957342729/1 [00:00<00:00,  1.91it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
#
# openssl-3.5.1        | 3.0 MB    | : 100% 1.0/1 [00:00<00:00,  1.65it/s]
#
#
# python-3.10.18       | 23.9 MB   | : 100% 1.0/1 [00:00<00:00,  1.91it/s]
#
#
#
#
#
#
#
# libgcc-15.1.0        | 806 KB    | : 100% 1.0/1 [00:01<00:00,  1.08it/s]
#
#
#
#
#
#
#
# libgcc-15.1.0        | 806 KB    | : 100% 1.0/1 [00:01<00:00,  1.08it/s]
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
# pip-25.1.1           | 1.2 MB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
# ld_impl_linux-64-2.4 | 660 KB    | : 100% 1.0/1 [00:01<00:00,  1.16s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
# libgomp-15.1.0       | 437 KB    | : 100% 1.0/1 [00:01<00:00,  1.21s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
# readline-8.2         | 276 KB    | : 100% 1.0/1 [00:01<00:00,  1.26s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# ca-certificates-2025 | 152 KB    | : 100% 1.0/1 [00:01<00:00,  1.29s/it]
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | : 100% 1.0/1 [00:01<00:00,  1.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 110 KB    | : 100% 1.0/1 [00:01<00:00,  1.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:01<00:00,  1.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | : 100% 1.0/1 [00:01<00:00,  1.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:01<00:00,  1.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 56 KB     | : 100% 1.0/1 [00:01<00:00,  1.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | : 100% 1.0/1 [00:01<00:00,  1.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 73 KB     | : 100% 1.0/1 [00:01<00:00,  1.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:01<00:00,  2.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnsl-2.0.1         | 33 KB     | : 100% 1.0/1 [00:01<00:00,  2.08s/it]
# icu-75.1             | 11.6 MB   | : 100% 1.0/1 [00:02<00:00,  4.94it/s]
#
#
#
#
#
#
# ncurses-6.5          | 871 KB    | : 100% 1.0/1 [00:02<00:00,  2.38s/it]
#
#
#
#
#
#
# python-3.10.18       | 23.9 MB   | : 100% 1.0/1 [00:03<00:00,  1.91it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate pinsage_env
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
# Looking in indexes: https://download.pytorch.org/whl/cu118
# Collecting torch==2.1.0+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torch-2.1.0%2Bcu118-cp310-cp310-linux_x86_64.whl (2325.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 GB 19.9 MB/s eta 0:00:00
# Collecting torchvision==0.16.0+cu118
#   Downloading https://download.pytorch.org/whl/cu118/torchvision-0.16.0%2Bcu118-cp310-cp310-linux_x86_64.whl (6.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 138.7 MB/s eta 0:00:00
# Collecting torchaudio==2.1.0
#   Downloading https://download.pytorch.org/whl/cu118/torchaudio-2.1.0%2Bcu118-cp310-cp310-linux_x86_64.whl (3.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 113.8 MB/s eta 0:00:00
# Collecting triton==2.1.0
#   Downloading https://download.pytorch.org/whl/triton-2.1.0-0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.2/89.2 MB 164.9 MB/s eta 0:00:00
# Collecting filelock (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl.metadata (2.8 kB)
# Collecting typing-extensions (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting sympy (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl.metadata (5.1 kB)
# Collecting jinja2 (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting fsspec (from torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl.metadata (11 kB)
# Collecting numpy (from torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (60 kB)
# Collecting requests (from torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/requests-2.28.1-py3-none-any.whl (62 kB)
# Collecting pillow!=8.3.*,>=5.3.0 (from torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (9.1 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/MarkupSafe-2.1.5-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25 kB)
# Collecting charset-normalizer<3,>=2 (from requests->torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/charset_normalizer-2.1.1-py3-none-any.whl (39 kB)
# Collecting idna<4,>=2.5 (from requests->torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<1.27,>=1.21.1 (from requests->torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/urllib3-1.26.13-py2.py3-none-any.whl (140 kB)
# Collecting certifi>=2017.4.17 (from requests->torchvision==0.16.0+cu118)
#   Downloading https://download.pytorch.org/whl/certifi-2022.12.7-py3-none-any.whl (155 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch==2.1.0+cu118)
#   Downloading https://download.pytorch.org/whl/mpmath-1.3.0-py3-none-any.whl (536 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 26.1 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/pillow-11.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 145.7 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/filelock-3.13.1-py3-none-any.whl (11 kB)
# Downloading https://download.pytorch.org/whl/fsspec-2024.6.1-py3-none-any.whl (177 kB)
# Downloading https://download.pytorch.org/whl/Jinja2-3.1.4-py3-none-any.whl (133 kB)
# Downloading https://download.pytorch.org/whl/networkx-3.3-py3-none-any.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 94.0 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/numpy-2.1.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.3/16.3 MB 184.4 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/sympy-1.13.3-py3-none-any.whl (6.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 178.2 MB/s eta 0:00:00
# Downloading https://download.pytorch.org/whl/typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Installing collected packages: mpmath, urllib3, typing-extensions, sympy, pillow, numpy, networkx, MarkupSafe, idna, fsspec, filelock, charset-normalizer, certifi, triton, requests, jinja2, torch, torchvision, torchaudio
#
# Successfully installed MarkupSafe-2.1.5 certifi-2022.12.7 charset-normalizer-2.1.1 filelock-3.13.1 fsspec-2024.6.1 idna-3.4 jinja2-3.1.4 mpmath-1.3.0 networkx-3.3 numpy-2.1.2 pillow-11.0.0 requests-2.28.1 sympy-1.13.3 torch-2.1.0+cu118 torchaudio-2.1.0+cu118 torchvision-0.16.0+cu118 triton-2.1.0 typing-extensions-4.12.2 urllib3-1.26.13
#
# Channels:
#  - dglteam/label/cu118
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.2
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pinsage_env
#
#   added / updated specs:
#     - dgl=2.0.0
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-python-1.1.0        |  py310hf71b8c6_3         343 KB  conda-forge
#     certifi-2025.7.14          |     pyhd8ed1ab_0         156 KB  conda-forge
#     cffi-1.17.1                |  py310h8deb56e_0         238 KB  conda-forge
#     charset-normalizer-3.4.2   |     pyhd8ed1ab_0          49 KB  conda-forge
#     dgl-2.0.0.cu118            |          py310_0       644.1 MB  dglteam/label/cu118
#     h2-4.2.0                   |     pyhd8ed1ab_0          53 KB  conda-forge
#     hpack-4.1.0                |     pyhd8ed1ab_0          30 KB  conda-forge
#     hyperframe-6.1.0           |     pyhd8ed1ab_0          17 KB  conda-forge
#     libblas-3.9.0              |32_h59b9bed_openblas          17 KB  conda-forge
#     libcblas-3.9.0             |32_he106b2a_openblas          17 KB  conda-forge
#     libgfortran-15.1.0         |       h69a702a_3          28 KB  conda-forge
#     libgfortran5-15.1.0        |       hcea5267_3         1.5 MB  conda-forge
#     liblapack-3.9.0            |32_h7ac8fdf_openblas          17 KB  conda-forge
#     libopenblas-0.3.30         |pthreads_h94d23a6_0         5.6 MB  conda-forge
#     networkx-3.4.2             |     pyh267e887_2         1.2 MB  conda-forge
#     numpy-2.2.6                |  py310hefbff90_0         7.5 MB  conda-forge
#     psutil-7.0.0               |  py310ha75aee5_0         346 KB  conda-forge
#     python_abi-3.10            |          8_cp310           7 KB  conda-forge
#     requests-2.32.4            |     pyhd8ed1ab_0          58 KB  conda-forge
#     scipy-1.15.2               |  py310h1d65ade_0        15.7 MB  conda-forge
#     urllib3-2.5.0              |     pyhd8ed1ab_0          99 KB  conda-forge
#     zstandard-0.23.0           |  py310ha75aee5_2         705 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:       677.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py310hf71b8c6_3
#   certifi            conda-forge/noarch::certifi-2025.7.14-pyhd8ed1ab_0
#   cffi               conda-forge/linux-64::cffi-1.17.1-py310h8deb56e_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.4.2-pyhd8ed1ab_0
#   colorama           conda-forge/noarch::colorama-0.4.6-pyhd8ed1ab_1
#   dgl                dglteam/label/cu118/linux-64::dgl-2.0.0.cu118-py310_0
#   h2                 conda-forge/noarch::h2-4.2.0-pyhd8ed1ab_0
#   hpack              conda-forge/noarch::hpack-4.1.0-pyhd8ed1ab_0
#   hyperframe         conda-forge/noarch::hyperframe-6.1.0-pyhd8ed1ab_0
#   idna               conda-forge/noarch::idna-3.10-pyhd8ed1ab_1
#   libblas            conda-forge/linux-64::libblas-3.9.0-32_h59b9bed_openblas
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-32_he106b2a_openblas
#   libgfortran        conda-forge/linux-64::libgfortran-15.1.0-h69a702a_3
#   libgfortran5       conda-forge/linux-64::libgfortran5-15.1.0-hcea5267_3
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-32_h7ac8fdf_openblas
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.30-pthreads_h94d23a6_0
#   networkx           conda-forge/noarch::networkx-3.4.2-pyh267e887_2
#   numpy              conda-forge/linux-64::numpy-2.2.6-py310hefbff90_0
#   psutil             conda-forge/linux-64::psutil-7.0.0-py310ha75aee5_0
#   pycparser          conda-forge/noarch::pycparser-2.22-pyh29332c3_1
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha55dd90_7
#   python_abi         conda-forge/noarch::python_abi-3.10-8_cp310
#   requests           conda-forge/noarch::requests-2.32.4-pyhd8ed1ab_0
#   scipy              conda-forge/linux-64::scipy-1.15.2-py310h1d65ade_0
#   tqdm               conda-forge/noarch::tqdm-4.67.1-pyhd8ed1ab_1
#   urllib3            conda-forge/noarch::urllib3-2.5.0-pyhd8ed1ab_0
#   zstandard          conda-forge/linux-64::zstandard-0.23.0-py310ha75aee5_2
#
#
#
# Downloading and Extracting Packages:
# dgl-2.0.0.cu118      | 644.1 MB  | :   0% 0/1 [00:00<?, ?it/s]
# scipy-1.15.2         | 15.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
# numpy-2.2.6          | 7.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libopenblas-0.3.30   | 5.6 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# networkx-3.4.2       | 1.2 MB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# zstandard-0.23.0     | 705 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# psutil-7.0.0         | 346 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# brotli-python-1.1.0  | 343 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 238 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# urllib3-2.5.0        | 99 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.4      | 58 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# h2-4.2.0             | 53 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 49 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hpack-4.1.0          | 30 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperframe-6.1.0     | 17 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
# scipy-1.15.2         | 15.7 MB   | :  27% 0.2714515796668364/1 [00:00<00:00,  2.71it/s]
#
# numpy-2.2.6          | 7.5 MB    | :  30% 0.30305134897950314/1 [00:00<00:00,  3.03it/s]
#
#
# libopenblas-0.3.30   | 5.6 MB    | :  49% 0.4928918731500828/1 [00:00<00:00,  4.93it/s]
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  8.83it/s]
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  8.83it/s]
#
#
#
#
# networkx-3.4.2       | 1.2 MB    | :   1% 0.012951696748162857/1 [00:00<00:11, 11.95s/it]
#
#
#
#
# networkx-3.4.2       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00, 11.95s/it]
# scipy-1.15.2         | 15.7 MB   | :  78% 0.7794253077933796/1 [00:00<00:00,  4.10it/s]
#
#
# libopenblas-0.3.30   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.46it/s]
#
#
# libopenblas-0.3.30   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.46it/s]
#
#
#
#
#
# zstandard-0.23.0     | 705 KB    | :   2% 0.02268878121196091/1 [00:00<00:09,  9.66s/it]
#
#
#
#
#
# zstandard-0.23.0     | 705 KB    | : 100% 1.0/1 [00:00<00:00,  9.66s/it]
#
#
#
# libgfortran5-15.1.0  | 1.5 MB    | : 100% 1.0/1 [00:00<00:00,  8.83it/s]
#
# numpy-2.2.6          | 7.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.93it/s]
#
# numpy-2.2.6          | 7.5 MB    | : 100% 1.0/1 [00:00<00:00,  3.93it/s]
#
#
#
#
#
#
# psutil-7.0.0         | 346 KB    | :   5% 0.046220336496688066/1 [00:00<00:05,  5.51s/it]
#
#
#
#
#
#
# psutil-7.0.0         | 346 KB    | : 100% 1.0/1 [00:00<00:00,  5.51s/it]
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 238 KB    | :   7% 0.06727657966920159/1 [00:00<00:04,  4.37s/it]
#
#
#
#
#
#
#
# brotli-python-1.1.0  | 343 KB    | :   5% 0.04660357661970469/1 [00:00<00:06,  6.41s/it]
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 238 KB    | : 100% 1.0/1 [00:00<00:00,  4.37s/it]
#
#
#
#
#
# zstandard-0.23.0     | 705 KB    | : 100% 1.0/1 [00:00<00:00,  9.66s/it]
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | :  10% 0.10255704046821695/1 [00:00<00:02,  3.03s/it]
#
#
#
#
#
#
#
# brotli-python-1.1.0  | 343 KB    | : 100% 1.0/1 [00:00<00:00,  6.41s/it]
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  3.03s/it]
#
#
#
#
#
#
#
#
#
#
# urllib3-2.5.0        | 99 KB     | :  16% 0.16104585442571387/1 [00:00<00:01,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
# urllib3-2.5.0        | 99 KB     | : 100% 1.0/1 [00:00<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# h2-4.2.0             | 53 KB     | :  30% 0.30403800475059384/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# h2-4.2.0             | 53 KB     | : 100% 1.0/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.4      | 58 KB     | :  28% 0.2757924150352652/1 [00:00<00:01,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.4      | 58 KB     | : 100% 1.0/1 [00:00<00:00,  1.40s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 49 KB     | :  32% 0.32455775440264656/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 49 KB     | : 100% 1.0/1 [00:00<00:00,  1.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hpack-4.1.0          | 30 KB     | :  53% 0.5331424294686148/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hpack-4.1.0          | 30 KB     | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperframe-6.1.0     | 17 KB     | :  94% 0.9417715698108869/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | :  56% 0.5638572461024882/1 [00:00<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperframe-6.1.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | :  95% 0.9454125793421811/1 [00:00<00:00,  2.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | : 100% 1.0/1 [00:00<00:00,  2.14it/s]
# scipy-1.15.2         | 15.7 MB   | : 100% 1.0/1 [00:00<00:00,  4.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libopenblas-0.3.30   | 5.6 MB    | : 100% 1.0/1 [00:00<00:00,  4.46it/s]
#
#
#
#
#
#
# psutil-7.0.0         | 346 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
# psutil-7.0.0         | 346 KB    | : 100% 1.0/1 [00:00<00:00,  1.79it/s]
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 238 KB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
#
#
#
#
#
#
#
#
# cffi-1.17.1          | 238 KB    | : 100% 1.0/1 [00:00<00:00,  1.67it/s]
#
#
#
#
#
#
#
# brotli-python-1.1.0  | 343 KB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
#
#
#
#
#
#
#
# brotli-python-1.1.0  | 343 KB    | : 100% 1.0/1 [00:00<00:00,  1.61it/s]
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
#
#
# certifi-2025.7.14    | 156 KB    | : 100% 1.0/1 [00:00<00:00,  1.54it/s]
#
#
#
#
#
#
#
#
#
#
# urllib3-2.5.0        | 99 KB     | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
#
#
#
#
#
#
#
#
#
#
# urllib3-2.5.0        | 99 KB     | : 100% 1.0/1 [00:00<00:00,  1.43it/s]
#
#
#
#
# networkx-3.4.2       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
#
#
# networkx-3.4.2       | 1.2 MB    | : 100% 1.0/1 [00:00<00:00,  1.37it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# h2-4.2.0             | 53 KB     | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# h2-4.2.0             | 53 KB     | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.4      | 58 KB     | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
# requests-2.32.4      | 58 KB     | : 100% 1.0/1 [00:00<00:00,  1.32it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hpack-4.1.0          | 30 KB     | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hpack-4.1.0          | 30 KB     | : 100% 1.0/1 [00:00<00:00,  1.18it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 49 KB     | : 100% 1.0/1 [00:00<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# charset-normalizer-3 | 49 KB     | : 100% 1.0/1 [00:00<00:00,  1.25it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hyperframe-6.1.0     | 17 KB     | : 100% 1.0/1 [00:00<00:00,  2.20it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgfortran-15.1.0   | 28 KB     | : 100% 1.0/1 [00:00<00:00,  1.10it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libblas-3.9.0        | 17 KB     | : 100% 1.0/1 [00:00<00:00,  2.14it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# numpy-2.2.6          | 7.5 MB    | : 100% 1.0/1 [00:01<00:00,  3.93it/s]
# dgl-2.0.0.cu118      | 644.1 MB  | : 100% 1.0/1 [02:30<00:00, 63.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# Collecting numpy<2.0
#   Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
# Downloading numpy-1.26.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 190.2 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.1.2
#     Uninstalling numpy-2.1.2:
#       Successfully uninstalled numpy-2.1.2
# Successfully installed numpy-1.26.4
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dgl 2.0.0+cu118 requires torchdata>=0.5.0, which is not installed.
#
# Collecting pandas==2.1.3
#   Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (1.15.2)
# Requirement already satisfied: tqdm in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (4.67.1)
# Collecting torchtext==0.15.2
#   Downloading torchtext-0.15.2-cp310-cp310-manylinux1_x86_64.whl.metadata (7.4 kB)
# Collecting torchdata==0.6.1
#   Downloading torchdata-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: filelock in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (3.13.1)
# Requirement already satisfied: fsspec in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (2024.6.1)
# Requirement already satisfied: jinja2 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (3.1.4)
# Collecting networkx==3.2
#   Downloading networkx-3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: sympy in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (1.13.3)
# Requirement already satisfied: requests in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (2.28.1)
# Requirement already satisfied: pillow in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (11.0.0)
# Requirement already satisfied: typing_extensions in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (4.12.2)
# Collecting ipython
#   Downloading ipython-8.37.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting dask[dataframe]
#   Downloading dask-2025.7.0-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from pandas==2.1.3) (1.26.4)
# Collecting python-dateutil>=2.8.2 (from pandas==2.1.3)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.1.3)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.1 (from pandas==2.1.3)
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting torch==2.0.1 (from torchtext==0.15.2)
#   Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl.metadata (24 kB)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torchdata==0.6.1) (1.26.13)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1->torchtext==0.15.2)
#   Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: setuptools in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchtext==0.15.2) (80.9.0)
# Requirement already satisfied: wheel in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1->torchtext==0.15.2) (0.45.1)
# Collecting cmake (from triton==2.0.0->torch==2.0.1->torchtext==0.15.2)
#   Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Collecting lit (from triton==2.0.0->torch==2.0.1->torchtext==0.15.2)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Collecting click>=8.1 (from dask[dataframe])
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting cloudpickle>=3.0.0 (from dask[dataframe])
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting packaging>=20.0 (from dask[dataframe])
#   Downloading packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# Collecting partd>=1.4.0 (from dask[dataframe])
#   Downloading partd-1.4.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting pyyaml>=5.3.1 (from dask[dataframe])
#   Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.1 kB)
# Collecting toolz>=0.10.0 (from dask[dataframe])
#   Downloading toolz-1.0.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting importlib_metadata>=4.13.0 (from dask[dataframe])
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting pyarrow>=14.0.1 (from dask[dataframe])
#   Downloading pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from jinja2) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from sympy) (1.3.0)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests) (2022.12.7)
# Collecting decorator (from ipython)
#   Downloading decorator-5.2.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting exceptiongroup (from ipython)
#   Downloading exceptiongroup-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting jedi>=0.16 (from ipython)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting matplotlib-inline (from ipython)
#   Downloading matplotlib_inline-0.1.7-py3-none-any.whl.metadata (3.9 kB)
# Collecting pexpect>4.3 (from ipython)
#   Downloading pexpect-4.9.0-py2.py3-none-any.whl.metadata (2.5 kB)
# Collecting prompt_toolkit<3.1.0,>=3.0.41 (from ipython)
#   Downloading prompt_toolkit-3.0.51-py3-none-any.whl.metadata (6.4 kB)
# Collecting pygments>=2.4.0 (from ipython)
#   Downloading pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting stack_data (from ipython)
#   Downloading stack_data-0.6.3-py3-none-any.whl.metadata (18 kB)
# Collecting traitlets>=5.13.0 (from ipython)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting wcwidth (from prompt_toolkit<3.1.0,>=3.0.41->ipython)
#   Downloading wcwidth-0.2.13-py2.py3-none-any.whl.metadata (14 kB)
# Collecting zipp>=3.20 (from importlib_metadata>=4.13.0->dask[dataframe])
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting parso<0.9.0,>=0.8.4 (from jedi>=0.16->ipython)
#   Downloading parso-0.8.4-py2.py3-none-any.whl.metadata (7.7 kB)
# Collecting locket (from partd>=1.4.0->dask[dataframe])
#   Downloading locket-1.0.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Collecting ptyprocess>=0.5 (from pexpect>4.3->ipython)
#   Downloading ptyprocess-0.7.0-py2.py3-none-any.whl.metadata (1.3 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.1.3)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting executing>=1.2.0 (from stack_data->ipython)
#   Downloading executing-2.2.0-py2.py3-none-any.whl.metadata (8.9 kB)
# Collecting asttokens>=2.1.0 (from stack_data->ipython)
#   Downloading asttokens-3.0.0-py3-none-any.whl.metadata (4.7 kB)
# Collecting pure-eval (from stack_data->ipython)
#   Downloading pure_eval-0.2.3-py3-none-any.whl.metadata (6.3 kB)
# Downloading pandas-2.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 55.9 MB/s eta 0:00:00
# Downloading torchtext-0.15.2-cp310-cp310-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 92.4 MB/s eta 0:00:00
# Downloading torchdata-0.6.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 10.7 MB/s eta 0:00:00
# Downloading networkx-3.2-py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 78.6 MB/s eta 0:00:00
# Downloading torch-2.0.1-cp310-cp310-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 35.7 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 71.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 33.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 127.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 53.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 39.4 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 126.4 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 68.9 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 107.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 62.2 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 113.3 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Downloading triton-2.0.0-1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 108.2 MB/s eta 0:00:00
# Downloading dask-2025.7.0-py3-none-any.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 90.0 MB/s eta 0:00:00
# Downloading ipython-8.37.0-py3-none-any.whl (831 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 831.9/831.9 kB 57.2 MB/s eta 0:00:00
# Downloading prompt_toolkit-3.0.51-py3-none-any.whl (387 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 85.1 MB/s eta 0:00:00
# Downloading parso-0.8.4-py2.py3-none-any.whl (103 kB)
# Downloading packaging-25.0-py3-none-any.whl (66 kB)
# Downloading partd-1.4.2-py3-none-any.whl (18 kB)
# Downloading pexpect-4.9.0-py2.py3-none-any.whl (63 kB)
# Downloading ptyprocess-0.7.0-py2.py3-none-any.whl (13 kB)
# Downloading pyarrow-21.0.0-cp310-cp310-manylinux_2_28_x86_64.whl (42.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.7/42.7 MB 98.9 MB/s eta 0:00:00
# Downloading pygments-2.19.2-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 71.5 MB/s eta 0:00:00
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading PyYAML-6.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (751 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 751.2/751.2 kB 48.5 MB/s eta 0:00:00
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading toolz-1.0.0-py3-none-any.whl (56 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading cmake-4.0.3-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (27.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 27.9/27.9 MB 131.4 MB/s eta 0:00:00
# Downloading decorator-5.2.1-py3-none-any.whl (9.2 kB)
# Downloading exceptiongroup-1.3.0-py3-none-any.whl (16 kB)
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
# Downloading locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Downloading matplotlib_inline-0.1.7-py3-none-any.whl (9.9 kB)
# Downloading stack_data-0.6.3-py3-none-any.whl (24 kB)
# Downloading asttokens-3.0.0-py3-none-any.whl (26 kB)
# Downloading executing-2.2.0-py2.py3-none-any.whl (26 kB)
# Downloading pure_eval-0.2.3-py3-none-any.whl (11 kB)
# Downloading wcwidth-0.2.13-py2.py3-none-any.whl (34 kB)
# Installing collected packages: wcwidth, pytz, pure-eval, ptyprocess, lit, zipp, tzdata, traitlets, toolz, six, pyyaml, pygments, pyarrow, prompt_toolkit, pexpect, parso, packaging, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, networkx, locket, executing, exceptiongroup, decorator, cmake, cloudpickle, click, asttokens, stack_data, python-dateutil, partd, nvidia-cusolver-cu11, nvidia-cudnn-cu11, matplotlib-inline, jedi, importlib_metadata, pandas, ipython, dask, triton, torch, torchdata, torchtext
#   Attempting uninstall: networkx
#     Found existing installation: networkx 3.3
#     Uninstalling networkx-3.3:
#       Successfully uninstalled networkx-3.3
#   Attempting uninstall: triton
#     Found existing installation: triton 2.1.0
#     Uninstalling triton-2.1.0:
#       Successfully uninstalled triton-2.1.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.1.0+cu118
#     Uninstalling torch-2.1.0+cu118:
#       Successfully uninstalled torch-2.1.0+cu118
#
# Successfully installed asttokens-3.0.0 click-8.2.1 cloudpickle-3.1.1 cmake-4.0.3 dask-2025.7.0 decorator-5.2.1 exceptiongroup-1.3.0 executing-2.2.0 importlib_metadata-8.7.0 ipython-8.37.0 jedi-0.19.2 lit-18.1.8 locket-1.0.0 matplotlib-inline-0.1.7 networkx-3.2 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 packaging-25.0 pandas-2.1.3 parso-0.8.4 partd-1.4.2 pexpect-4.9.0 prompt_toolkit-3.0.51 ptyprocess-0.7.0 pure-eval-0.2.3 pyarrow-21.0.0 pygments-2.19.2 python-dateutil-2.9.0.post0 pytz-2025.2 pyyaml-6.0.2 six-1.17.0 stack_data-0.6.3 toolz-1.0.0 torch-2.0.1 torchdata-0.6.1 torchtext-0.15.2 traitlets-5.14.3 triton-2.0.0 tzdata-2025.2 wcwidth-0.2.13 zipp-3.23.0
#
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.1.0+cu118 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
# torchvision 0.16.0+cu118 requires torch==2.1.0, but you have torch 2.0.1 which is incompatible.
#
# Collecting scikit-learn
#   Downloading scikit_learn-1.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (11 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.8.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from scikit-learn) (1.15.2)
# Collecting joblib>=1.2.0 (from scikit-learn)
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.59.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (107 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.2 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from matplotlib) (11.0.0)
# Collecting pyparsing>=2.3.1 (from matplotlib)
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading scikit_learn-1.7.1-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 90.3 MB/s eta 0:00:00
# Downloading matplotlib-3.10.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 134.2 MB/s eta 0:00:00
# Downloading contourpy-1.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (325 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (4.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 133.6 MB/s eta 0:00:00
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading kiwisolver-1.4.8-cp310-cp310-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.9 MB/s eta 0:00:00
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, pyparsing, kiwisolver, joblib, fonttools, cycler, contourpy, scikit-learn, matplotlib
#
# Successfully installed contourpy-1.3.2 cycler-0.12.1 fonttools-4.59.0 joblib-1.5.1 kiwisolver-1.4.8 matplotlib-3.10.3 pyparsing-3.2.3 scikit-learn-1.7.1 threadpoolctl-3.6.0
#
# Looking in links: https://data.pyg.org/whl/torch-2.1.0+cu118.html
# Collecting torch-scatter
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu118/torch_scatter-2.1.2%2Bpt21cu118-cp310-cp310-linux_x86_64.whl (10.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 153.3 MB/s eta 0:00:00
# Collecting torch-sparse
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu118/torch_sparse-0.6.18%2Bpt21cu118-cp310-cp310-linux_x86_64.whl (4.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 137.4 MB/s eta 0:00:00
# Collecting torch-cluster
#   Downloading https://data.pyg.org/whl/torch-2.1.0%2Bcu118/torch_cluster-1.6.3%2Bpt21cu118-cp310-cp310-linux_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 94.9 MB/s eta 0:00:00
# Collecting torch-geometric
#   Downloading torch_geometric-2.6.1-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: scipy in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-sparse) (1.15.2)
# Collecting aiohttp (from torch-geometric)
#   Downloading aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.6 kB)
# Requirement already satisfied: fsspec in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (2024.6.1)
# Requirement already satisfied: jinja2 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (3.1.4)
# Requirement already satisfied: numpy in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (1.26.4)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (7.0.0)
# Requirement already satisfied: pyparsing in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (3.2.3)
# Requirement already satisfied: requests in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (2.28.1)
# Requirement already satisfied: tqdm in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from torch-geometric) (4.67.1)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->torch-geometric)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->torch-geometric)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp->torch-geometric)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp->torch-geometric)
#   Downloading attrs-25.3.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp->torch-geometric)
#   Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->torch-geometric)
#   Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->torch-geometric)
#   Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->torch-geometric)
#   Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (73 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from multidict<7.0,>=4.5->aiohttp->torch-geometric) (4.12.2)
# Requirement already satisfied: idna>=2.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp->torch-geometric) (3.10)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from jinja2->torch-geometric) (2.1.5)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests->torch-geometric) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests->torch-geometric) (1.26.13)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/envs/pinsage_env/lib/python3.10/site-packages (from requests->torch-geometric) (2022.12.7)
# Downloading torch_geometric-2.6.1-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 59.6 MB/s eta 0:00:00
# Downloading aiohttp-3.12.14-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 52.4 MB/s eta 0:00:00
# Downloading async_timeout-5.0.1-py3-none-any.whl (6.2 kB)
# Downloading multidict-6.6.3-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (241 kB)
# Downloading yarl-1.20.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (326 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.3.0-py3-none-any.whl (63 kB)
# Downloading frozenlist-1.7.0-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (222 kB)
# Downloading propcache-0.3.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (198 kB)
# Installing collected packages: torch-scatter, propcache, multidict, frozenlist, attrs, async-timeout, aiohappyeyeballs, yarl, torch-sparse, torch-cluster, aiosignal, aiohttp, torch-geometric
#
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.12.14 aiosignal-1.4.0 async-timeout-5.0.1 attrs-25.3.0 frozenlist-1.7.0 multidict-6.6.3 propcache-0.3.2 torch-cluster-1.6.3+pt21cu118 torch-geometric-2.6.1 torch-scatter-2.1.2+pt21cu118 torch-sparse-0.6.18+pt21cu118 yarl-1.20.1
#
# Setting the default backend to "pytorch". You can change it in the ~/.dgl/config.json file or export the DGLBACKEND environment variable.  Valid options are: pytorch, mxnet, tensorflow (all lowercase)
# ✅ Torch: 2.0.1+cu117 | CUDA: True | DGL: 2.0.0+cu118 | Sklearn: 1.7.1
#
# DGL backend not selected or invalid.  Assuming PyTorch for now.

# %%
# clean up env if necessary
# !conda remove -n pinsage_env --all -y
# Out:
# Remove all packages in environment /usr/local/envs/pinsage_env:
#
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/pinsage_env
#
#
# The following packages will be REMOVED:
#
#   _libgcc_mutex-0.1-conda_forge
#   _openmp_mutex-4.5-2_gnu
#   brotli-python-1.1.0-py310hf71b8c6_3
#   bzip2-1.0.8-h4bc722e_7
#   ca-certificates-2025.7.14-hbd8a1cb_0
#   certifi-2025.7.14-pyhd8ed1ab_0
#   cffi-1.17.1-py310h8deb56e_0
#   charset-normalizer-3.4.2-pyhd8ed1ab_0
#   colorama-0.4.6-pyhd8ed1ab_1
#   dgl-2.0.0.cu118-py310_0
#   h2-4.2.0-pyhd8ed1ab_0
#   hpack-4.1.0-pyhd8ed1ab_0
#   hyperframe-6.1.0-pyhd8ed1ab_0
#   icu-75.1-he02047a_0
#   idna-3.10-pyhd8ed1ab_1
#   ld_impl_linux-64-2.44-h1423503_1
#   libblas-3.9.0-32_h59b9bed_openblas
#   libcblas-3.9.0-32_he106b2a_openblas
#   libexpat-2.7.1-hecca717_0
#   libffi-3.4.6-h2dba641_1
#   libgcc-15.1.0-h767d61c_3
#   libgcc-ng-15.1.0-h69a702a_3
#   libgfortran-15.1.0-h69a702a_3
#   libgfortran5-15.1.0-hcea5267_3
#   libgomp-15.1.0-h767d61c_3
#   liblapack-3.9.0-32_h7ac8fdf_openblas
#   liblzma-5.8.1-hb9d3cd8_2
#   libnsl-2.0.1-hb9d3cd8_1
#   libopenblas-0.3.30-pthreads_h94d23a6_0
#   libsqlite-3.50.3-hee844dc_0
#   libstdcxx-15.1.0-h8f9b012_3
#   libstdcxx-ng-15.1.0-h4852527_3
#   libuuid-2.38.1-h0b41bf4_0
#   libxcrypt-4.4.36-hd590300_1
#   libzlib-1.3.1-hb9d3cd8_2
#   ncurses-6.5-h2d0b736_3
#   networkx-3.4.2-pyh267e887_2
#   numpy-2.2.6-py310hefbff90_0
#   openssl-3.5.1-h7b32b05_0
#   pip-25.1.1-pyh8b19718_0
#   psutil-7.0.0-py310ha75aee5_0
#   pycparser-2.22-pyh29332c3_1
#   pysocks-1.7.1-pyha55dd90_7
#   python-3.10.18-hd6af730_0_cpython
#   python_abi-3.10-8_cp310
#   readline-8.2-h8c095d6_2
#   requests-2.32.4-pyhd8ed1ab_0
#   scipy-1.15.2-py310h1d65ade_0
#   setuptools-80.9.0-pyhff2d567_0
#   tk-8.6.13-noxft_hd72426e_102
#   tqdm-4.67.1-pyhd8ed1ab_1
#   tzdata-2025b-h78e105d_0
#   urllib3-2.5.0-pyhd8ed1ab_0
#   wheel-0.45.1-pyhd8ed1ab_1
#   zstandard-0.23.0-py310ha75aee5_2
#
#
#
# Downloading and Extracting Packages:
#
# done
# done
# done

# %%
# test whether pinsage sampler package available to use
# change dir to script folder
import os
os.chdir(GOOGLE_DRIVE_PATH + "/scripts")
# run on env
# !conda run -n pinsage_env python test_installation.py
# Out:
# 🔍 Starting environment test for DGL PinSAGE example...
#
# ✅ Built-in modules loaded (os, re, pickle, argparse)
# ✅ Data modules loaded (numpy, pandas, scipy, dask)
# ✅ Torch loaded (version: 2.0.1+cu117, CUDA: True)
# ✅ DGL loaded (version: 2.0.0+cu118)
# ✅ TorchText loaded (tokenizer, vocab)
# ✅ tqdm loaded
# ✅ pandas.api.types helpers loaded
# ✅ Local module found: sampler.py
# ⚠️  Local module NOT found: evaluation.py (expected if not copied yet)
# ⚠️  Local module NOT found: layers.py (expected if not copied yet)
# ⚠️  Local module NOT found: builder.py (expected if not copied yet)
# ⚠️  Local module NOT found: data_utils.py (expected if not copied yet)
#
# 🎉 Environment test complete!
# ⚠️  Note: Some local scripts were not found. If you're setting up the full repo, be sure to include:
#   - evaluation.py
#   - layers.py
#   - builder.py
#   - data_utils.py

# %% [markdown]
# # PinSage Model Training

# %%
# step 1: data preparation
# %cd /content/drive/MyDrive/Colab\ Notebooks/Group-Project/scripts/
# !conda run -n pinsage_env --no-capture-output python test_datautils.py
# Out:
# /content
# 🔍 Loading data and building inductive split...
#
# Generated 515791 negative edges
# Generated 32866 negative edges
# ✅ Train Graph:
#   - Num nodes: 322152
#   - Num edges: 515791
#
# ✅ Validation Graph:
#   - Num nodes: 80539
#   - Num edges: 32866
#
# ✅ Train Edges / Labels:
#   - Positive + Negative edges: 1031582
#   - Labels (sample): [1, 1, 1, 1, 1]
#
# ✅ Validation Edges / Labels:
#   - Positive + Negative edges: 65732
#   - Labels (sample): [1, 1, 1, 1, 1]
#
# 🎉 Data utility pipeline works! You can now feed train_feat_pairs and train_labels into a model.

# %%
# step2: build precomputed walks
# %cd /content/drive/MyDrive/Colab\ Notebooks/Group-Project/scripts/
# !conda run -n pinsage_env --no-capture-output python run_precompute_walks.py
# Out:
# /content
# 🔍 Loading graph...
#
# Generated 515791 negative edges
# Generated 32866 negative edges
# 🚶 Starting precomputation: 322152 nodes
# 100% 322152/322152 [03:07<00:00, 1715.71it/s]
# ✅ Saved precomputed neighbors (with probs) to /content/drive/MyDrive/Colab Notebooks/Group-Project/data/train_neighbors_precomputed.npy
# 🚶 Starting precomputation: 80539 nodes
# 100% 80539/80539 [00:42<00:00, 1894.96it/s]
# ✅ Saved precomputed neighbors (with probs) to /content/drive/MyDrive/Colab Notebooks/Group-Project/data/val_neighbors_precomputed.npy

# %%
# step2.1: check saved precomputed walks
import numpy as np

# Load the .npy file
data_path = "/content/drive/MyDrive/Colab Notebooks/Group-Project/data/train_neighbors_precomputed.npy"
neighbors_dict = np.load(data_path, allow_pickle=True).item()

# Check the number of nodes
print(f"Total nodes: {len(neighbors_dict)}")

# Look at one example (e.g., node 0)
node_id = 15657
if node_id in neighbors_dict:
    print(f"\nNode {node_id} neighbors:")
    print("Neighbors:", neighbors_dict[node_id]['neighbors'])
    print("Probs     :", neighbors_dict[node_id]['probs'])
else:
    print(f"Node {node_id} not in precomputed data.")
# Out:
# Total nodes: 322152
#
# Node 15657 neighbors:
# Neighbors: [86696, 265390, 282897, 296799]
# Probs     : [0.15625, 0.125, 0.46875, 0.25]

# %%
# step3: build sampler
# %cd /content/drive/MyDrive/Colab\ Notebooks/Group-Project/scripts/
# !conda run -n pinsage_env --no-capture-output python test_sampler.py
# Out:
# /content
# 🔍 Loading data and building inductive split...
#
# Generated 515791 negative edges
# Generated 32866 negative edges
#
# 🚀 Testing one batch from train_loader using PrecomputedSampler...
#
# ✅ Train heads: [119380, 295813, 209982, 247078]
# ✅ Train tails: [41483, 164710, 30344, 6644]
# ✅ Labels: [0, 0, 0, 1]
# ✅ Train Blocks: [140, 82, 36]
#
# 🧪 Testing one batch from val_loader using PrecomputedSampler...
#
# ✅ Val heads: [52043, 41178, 41702, 40321]
# ✅ Val tails: [56814, 50460, 8094, 53274]
# ✅ Labels: [1, 1, 1, 1]
# ✅ Val Blocks: [69, 55, 30]

# %%
# step4: train
# %cd /content/drive/MyDrive/Colab\ Notebooks/Group-Project/scripts/
# !conda run -n pinsage_env --no-capture-output python train_pinsage_model.py
# Out:
# /content
#
# 🔍 Loading data and building inductive split...
#
# Generated 515791 negative edges
# Generated 32866 negative edges
# ✅ Graph: 322152 nodes, 515791 edges
# ✅ Graph: 80539 nodes, 32866 edges
# ✅ Train edges: 1031582, Validation edges: 65732
#
# 📂 Loading precomputed walk dictionaries (NPY format)...
#
# ✅ Precomputed walk dicts loaded.
#
# 🎲 Trial 1/1
# 🔧 Config: {'batch_size': 512, 'num_epochs': 30, 'learning_rate': 0.0001, 'hidden_feats': 256, 'out_feats': 128, 'num_layers': 3, 'dropout': 0.25, 'train_ratio': 0.8}
#
# 📦 Preparing dataloaders...
#
# ✅ Epoch 1 | Loss: 0.6105 | AUC: 0.7593 | AP: 0.7579 | Val Loss: 0.5423 |Val AUC: 0.8708 | Val AP: 0.8739 |Time: 1869.74s | GPU: 6415.58 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_1.pth
# ✅ Epoch 2 | Loss: 0.5457 | AUC: 0.8470 | AP: 0.8496 | Val Loss: 0.5037 |Val AUC: 0.9100 | Val AP: 0.9140 |Time: 1873.14s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_2.pth
# ✅ Epoch 3 | Loss: 0.5256 | AUC: 0.8693 | AP: 0.8759 | Val Loss: 0.4837 |Val AUC: 0.9243 | Val AP: 0.9293 |Time: 1881.76s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_3.pth
# ✅ Epoch 4 | Loss: 0.5133 | AUC: 0.8812 | AP: 0.8901 | Val Loss: 0.4759 |Val AUC: 0.9299 | Val AP: 0.9362 |Time: 1890.69s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_4.pth
# ✅ Epoch 5 | Loss: 0.5051 | AUC: 0.8882 | AP: 0.8990 | Val Loss: 0.4659 |Val AUC: 0.9360 | Val AP: 0.9428 |Time: 1888.84s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_5.pth
# ✅ Epoch 6 | Loss: 0.4990 | AUC: 0.8932 | AP: 0.9050 | Val Loss: 0.4590 |Val AUC: 0.9387 | Val AP: 0.9466 |Time: 1897.17s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_6.pth
# ✅ Epoch 7 | Loss: 0.4940 | AUC: 0.8974 | AP: 0.9100 | Val Loss: 0.4557 |Val AUC: 0.9402 | Val AP: 0.9480 |Time: 1890.37s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_7.pth
# ✅ Epoch 8 | Loss: 0.4897 | AUC: 0.9010 | AP: 0.9139 | Val Loss: 0.4523 |Val AUC: 0.9437 | Val AP: 0.9520 |Time: 1892.21s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_8.pth
# ✅ Epoch 9 | Loss: 0.4861 | AUC: 0.9040 | AP: 0.9174 | Val Loss: 0.4510 |Val AUC: 0.9449 | Val AP: 0.9535 |Time: 1894.92s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_9.pth
# ✅ Epoch 10 | Loss: 0.4824 | AUC: 0.9068 | AP: 0.9204 | Val Loss: 0.4486 |Val AUC: 0.9467 | Val AP: 0.9542 |Time: 1890.67s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_10.pth
# ✅ Epoch 11 | Loss: 0.4794 | AUC: 0.9092 | AP: 0.9228 | Val Loss: 0.4469 |Val AUC: 0.9456 | Val AP: 0.9544 |Time: 1891.78s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_11.pth
# ✅ Epoch 12 | Loss: 0.4768 | AUC: 0.9114 | AP: 0.9250 | Val Loss: 0.4469 |Val AUC: 0.9472 | Val AP: 0.9557 |Time: 1886.02s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_12.pth
# ✅ Epoch 13 | Loss: 0.4742 | AUC: 0.9134 | AP: 0.9271 | Val Loss: 0.4436 |Val AUC: 0.9483 | Val AP: 0.9574 |Time: 1888.85s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_13.pth
# ✅ Epoch 14 | Loss: 0.4715 | AUC: 0.9152 | AP: 0.9290 | Val Loss: 0.4440 |Val AUC: 0.9495 | Val AP: 0.9586 |Time: 1884.70s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_14.pth
# ✅ Epoch 15 | Loss: 0.4694 | AUC: 0.9170 | AP: 0.9308 | Val Loss: 0.4394 |Val AUC: 0.9518 | Val AP: 0.9602 |Time: 1887.72s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_15.pth
# ✅ Epoch 16 | Loss: 0.4674 | AUC: 0.9183 | AP: 0.9322 | Val Loss: 0.4398 |Val AUC: 0.9521 | Val AP: 0.9606 |Time: 1880.31s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_16.pth
# ✅ Epoch 17 | Loss: 0.4647 | AUC: 0.9200 | AP: 0.9340 | Val Loss: 0.4380 |Val AUC: 0.9524 | Val AP: 0.9607 |Time: 1879.05s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_17.pth
# ✅ Epoch 18 | Loss: 0.4627 | AUC: 0.9216 | AP: 0.9354 | Val Loss: 0.4369 |Val AUC: 0.9526 | Val AP: 0.9611 |Time: 1880.44s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_18.pth
# ✅ Epoch 19 | Loss: 0.4607 | AUC: 0.9228 | AP: 0.9367 | Val Loss: 0.4356 |Val AUC: 0.9540 | Val AP: 0.9627 |Time: 1882.85s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_19.pth
# ✅ Epoch 20 | Loss: 0.4588 | AUC: 0.9240 | AP: 0.9379 | Val Loss: 0.4352 |Val AUC: 0.9533 | Val AP: 0.9623 |Time: 1878.80s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_20.pth
# ✅ Epoch 21 | Loss: 0.4568 | AUC: 0.9253 | AP: 0.9391 | Val Loss: 0.4343 |Val AUC: 0.9547 | Val AP: 0.9633 |Time: 1883.24s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_21.pth
# ✅ Epoch 22 | Loss: 0.4548 | AUC: 0.9265 | AP: 0.9403 | Val Loss: 0.4322 |Val AUC: 0.9551 | Val AP: 0.9640 |Time: 1872.30s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_22.pth
# ✅ Epoch 23 | Loss: 0.4531 | AUC: 0.9276 | AP: 0.9413 | Val Loss: 0.4322 |Val AUC: 0.9550 | Val AP: 0.9643 |Time: 1876.38s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_23.pth
# ✅ Epoch 24 | Loss: 0.4511 | AUC: 0.9286 | AP: 0.9424 | Val Loss: 0.4323 |Val AUC: 0.9551 | Val AP: 0.9640 |Time: 1879.05s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_24.pth
# ✅ Epoch 25 | Loss: 0.4493 | AUC: 0.9298 | AP: 0.9434 | Val Loss: 0.4306 |Val AUC: 0.9562 | Val AP: 0.9649 |Time: 1881.44s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_25.pth
# ✅ Epoch 26 | Loss: 0.4475 | AUC: 0.9308 | AP: 0.9443 | Val Loss: 0.4328 |Val AUC: 0.9551 | Val AP: 0.9641 |Time: 1874.45s | GPU: 6417.26 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_26.pth
# ✅ Epoch 27 | Loss: 0.4462 | AUC: 0.9315 | AP: 0.9450 | Val Loss: 0.4321 |Val AUC: 0.9544 | Val AP: 0.9639 |Time: 1887.71s | GPU: 6418.39 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_27.pth
# ✅ Epoch 28 | Loss: 0.4446 | AUC: 0.9323 | AP: 0.9457 | Val Loss: 0.4319 |Val AUC: 0.9556 | Val AP: 0.9646 |Time: 1873.64s | GPU: 6418.39 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_28.pth
# ✅ Epoch 29 | Loss: 0.4428 | AUC: 0.9330 | AP: 0.9466 | Val Loss: 0.4313 |Val AUC: 0.9560 | Val AP: 0.9654 |Time: 1879.90s | GPU: 6420.33 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_29.pth
# ✅ Epoch 30 | Loss: 0.4412 | AUC: 0.9339 | AP: 0.9473 | Val Loss: 0.4320 |Val AUC: 0.9544 | Val AP: 0.9642 |Time: 1884.19s | GPU: 6420.33 MB
# 💾 Checkpoint saved to /content/drive/MyDrive/Colab Notebooks/Group-Project/checkpoints/epoch_30.pth
# 🎯 Best epoch in trial 1: Epoch 25 with Val AUC: 0.9562
#
# 🏆 Best Config Across All Trials:
#   batch_size: 512
#   num_epochs: 30
#   learning_rate: 0.0001
#   hidden_feats: 256
#   out_feats: 128
#   num_layers: 3
#   dropout: 0.25
#   train_ratio: 0.8
# 🥇 Best Validation AUC: 0.9562
#
# 📮 Best model saved to: /content/drive/MyDrive/Colab Notebooks/Group-Project/model/best_pinsage_model.pth
# 📈 Saved training history plot to: /content/drive/MyDrive/Colab Notebooks/Group-Project/plot/training_history.png

# %%
# !nvidia-smi
# Out:
# Thu Jul 24 22:34:58 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             69W /  400W |       0MiB /  40960MiB |     56%      Default |
# |                                         |                        |             Disabled |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
# !lscpu
# Out:
# Architecture:             x86_64
#   CPU op-mode(s):         32-bit, 64-bit
#   Address sizes:          46 bits physical, 48 bits virtual
#   Byte Order:             Little Endian
# CPU(s):                   12
#   On-line CPU(s) list:    0-11
# Vendor ID:                GenuineIntel
#   Model name:             Intel(R) Xeon(R) CPU @ 2.20GHz
#     CPU family:           6
#     Model:                85
#     Thread(s) per core:   2
#     Core(s) per socket:   6
#     Socket(s):            1
#     Stepping:             7
#     BogoMIPS:             4400.52
#     Flags:                fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge m
#                           ca cmov pat pse36 clflush mmx fxsr sse sse2 ss ht sysc
#                           all nx pdpe1gb rdtscp lm constant_tsc rep_good nopl xt
#                           opology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq
#                            ssse3 fma cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt
#                            aes xsave avx f16c rdrand hypervisor lahf_lm abm 3dno
#                           wprefetch invpcid_single ssbd ibrs ibpb stibp ibrs_enh
#                           anced fsgsbase tsc_adjust bmi1 hle avx2 smep bmi2 erms
#                            invpcid rtm mpx avx512f avx512dq rdseed adx smap clfl
#                           ushopt clwb avx512cd avx512bw avx512vl xsaveopt xsavec
#                            xgetbv1 xsaves arat avx512_vnni md_clear arch_capabil
#                           ities
# Virtualization features:
#   Hypervisor vendor:      KVM
#   Virtualization type:    full
# Caches (sum of all):
#   L1d:                    192 KiB (6 instances)
#   L1i:                    192 KiB (6 instances)
#   L2:                     6 MiB (6 instances)
#   L3:                     38.5 MiB (1 instance)
# NUMA:
#   NUMA node(s):           1
#   NUMA node0 CPU(s):      0-11
# Vulnerabilities:
#   Gather data sampling:   Not affected
#   Itlb multihit:          Not affected
#   L1tf:                   Not affected
#   Mds:                    Not affected
#   Meltdown:               Not affected
#   Mmio stale data:        Vulnerable
#   Reg file data sampling: Not affected
#   Retbleed:               Vulnerable
#   Spec rstack overflow:   Not affected
#   Spec store bypass:      Vulnerable
#   Spectre v1:             Vulnerable: __user pointer sanitization and usercopy b
#                           arriers only; no swapgs barriers
#   Spectre v2:             Vulnerable; IBPB: disabled; STIBP: disabled; PBRSB-eIB
#                           RS: Vulnerable; BHI: Vulnerable
#   Srbds:                  Not affected
#   Tsx async abort:        Vulnerable
